# %%
futbolcular = ["Yunus", "Barış Alper", "Eren", "Uğurcan", "Abdülkerim"], [11, 53,
17, 1, 42]

# %%
print(futbolcular[0][3])
# Out:
# Uğurcan

# %%
print(f"{futbolcular[0][2]} isimli futbolcunun numarası {futbolcular[1][2]}")
# Out:
# Eren isimli futbolcunun numarası 17

# %%
futbolcular[0].append("Kaan")
futbolcular[1].append(23)

# %%
print(futbolcular)
# Out:
# (['Yunus', 'Barış Alper', 'Eren', 'Uğurcan', 'Abdülkerim', 'Kaan'], [11, 53, 17, 1, 42, 23])

# %%
futbolcular[0].pop()
futbolcular[1].pop()
# Out:
# 23

# %%
print(futbolcular)
# Out:
# (['Yunus', 'Barış Alper', 'Eren', 'Uğurcan', 'Abdülkerim'], [11, 53, 17, 1, 42])

# %%
futbolcular[0].remove("Barış Alper")
futbolcular[1].remove(53)

# %%
del futbolcular[0][0]
del futbolcular[1][0]

# %%
futbolcular[0].insert(4, "İlkay")
futbolcular[1].insert(4, 20)
