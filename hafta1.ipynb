# %%
print("merhaba python")
# Out:
# merhaba python

# %%
mesaj = "Bu örnekten sonra dersin bitmesini isteyenler el kaldırsın. Ama önce örneği herkesin yapması gerekiyor."

# %%
print(mesaj)
# Out:
# Bu örnekten sonra dersin bitmesini isteyenler el kaldırsın. Ama önce örneği herkesin yapması gerekiyor.
