# %%
arabalar = ["BMV", "Mercedes", "Opel", "Mazda"]
print(arabalar)
# Out:
# ['BMV', 'Mercedes', 'Opel', 'Mazda']

# %%
print(arabalar[2])
# Out:
# Opel

# %%
print(arabalar[-1])
# Out:
# Mazda

# %%
print(arabalar[0:3:2])
# Out:
# ['BMV', 'Opel']

# %%
arabalar = ["BMW", "Mercedes", "Opel", "Mazda", "Renault", "Fiat", "Toyota",
"Honda", "Hyundai", "Kia", "Ford", "Chevrolet", "Nissan", "Volkswagen", "Audi",
"Porsche", "Lexus", "Jaguar", "Land Rover", "Subaru"]

# %%
print(arabalar[3:5])
print(arabalar[3::2])
# Out:
# ['Mazda', 'Renault']
# ['Mazda', 'Fiat', 'Honda', 'Kia', 'Chevrolet', 'Volkswagen', 'Porsche', 'Jaguar', 'Subaru']

# %%
print(arabalar[3::-2])
# Out:
# ['Mazda', 'Mercedes']

# %%
print(arabalar[3:8:2])
# Out:
# ['Mazda', 'Fiat', 'Honda']

# %%
print(arabalar[7:2:-2])
# Out:
# ['Honda', 'Fiat', 'Mazda']

# %%
test = "asdasd"
type(test)
# Out:
# str

# %%
type(arabalar)
# Out:
# list

# %%
type(arabalar[0])
# Out:
# str

# %%
print(arabalar[2].upper())
# Out:
# OPEL

# %%
numaralar = [1, 10, 5, 10, 4, 9, 10]
type(numaralar[0])
# Out:
# int

# %%
deger = ["Ali", 10, 10.5, "Kamil"]
type(deger[1])
# Out:
# int

# %%
type(deger[3])
# Out:
# str

# %%
ogrenciler = ["Ali", "Veli", "Kemal", "Ayşe", "Hatice"], [123, 450, 
789, 101, 112]

# %%
print(ogrenciler[0][2])
# Out:
# Kemal

# %%
print(ogrenciler[-1][-1])
# Out:
# 112

# %%
print(f"{ogrenciler[0][3]} isimli öğrencinin numarası {ogrenciler[1][3]}")
# Out:
# Ayşe isimli öğrencinin numarası 101

# %%
ogrenciler[1][3] = 110

# %%
ogrenciler[0].append("Zeynep")
ogrenciler[1].append(113)

# %%
print(ogrenciler)
# Out:
# (['Ali', 'Veli', 'Kemal', 'Ayşe', 'Hatice', 'Zeynep'], [123, 450, 789, 110, 112, 113])

# %%
ogrenciler[0].pop()
ogrenciler[1].pop()
# Out:
# 113

# %%
print(ogrenciler)
# Out:
# (['Ali', 'Veli', 'Kemal', 'Ayşe', 'Hatice'], [123, 450, 789, 110, 112])

# %%
ogrenciler[0].remove("Kemal")
ogrenciler[1].remove(789)

# %%
del ogrenciler[0][0]
del ogrenciler[1][0]

# %%
ogrenciler[0].insert(1, "Mehmet")
ogrenciler[1].insert(1, 457)
