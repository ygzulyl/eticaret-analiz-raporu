# %%
class Araba:
    def __init__(self, marka, model, yil):
        self.marka = marka
        self.model = model
        self.yil = yil
        self.km = 0

    def bilgileri_goster(self):
        uzun_format = f"{self.marka} {self.model} {self.yil} ({self.km} km)"
        return uzun_format
    
    def km_guncelle(self, km):
        if km >= self.km:
            self.km = km
        else:
            print("Hata: Kilometre geri alınamaz.")

    def km_ekle(self, km):
        if km > 0:
            self.km += km
        else:
            print("Hata: Eklenen kilometre pozitif olmalıdır.")

    def benzin_doldur(self, litre):
        print(f"{litre} litre benzin dolduruldu.")

# %%
class ElektrikliAraba(Araba):
    def __init__(self, marka, model, yil, batarya_kapasitesi):
        super().__init__(marka, model, yil)
        self.batarya_kapasitesi = batarya_kapasitesi

    def batarya_bilgisi(self):
        print(f"{self.marka} {self.model} batarya kapasitesi: {self.batarya_kapasitesi} kWh")

# %%
ilk_elektrikli_arabam = ElektrikliAraba("Tesla", "Model 9", 2021, 75)
ilk_elektrikli_arabam.bilgileri_goster()

ilk_arabam = Araba("Toyota", "Corolla", 2020)
ilk_arabam.batarya_bilgisi()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       2 ilk_elektrikli_arabam.bilgileri_goster()
#       4 ilk_arabam = Araba("Toyota", "Corolla", 2020)
# ----> 5 ilk_arabam.batarya_bilgisi()
#
# AttributeError: 'Araba' object has no attribute 'batarya_bilgisi'

# %%
ilk_arabam.benzin_doldur(50)
ilk_elektrikli_arabam.benzin_doldur(50)
# Out:
# 50 litre benzin dolduruldu.
# 50 litre benzin dolduruldu.

# %%
class Araba:
    def __init__(self, marka, model, yil):
        self.marka = marka
        self.model = model
        self.yil = yil
        self.km = 0

    def bilgileri_goster(self):
        uzun_format = f"{self.marka} {self.model} {self.yil} ({self.km} km)"
        return uzun_format
    
    def km_guncelle(self, km):
        if km >= self.km:
            self.km = km
        else:
            print("Hata: Kilometre geri alınamaz.")

    def km_ekle(self, km):
        if km > 0:
            self.km += km
        else:
            print("Hata: Eklenen kilometre pozitif olmalıdır.")

    def benzin_doldur(self, litre):
        print(f"{litre} litre benzin dolduruldu.")

# %%
class Batarya:
    def __init__(self, kapasite_kwh):
        self.kapasite_kwh = kapasite_kwh

    def bilgileri_goster(self):
        print(f"Batarya kapasitesi: {self.kapasite_kwh} kwh")

def mesafe_hesapla(self):
    if self.kapasite_kwh == 75:
        mesafe = 350
        print(f"Bu batarya ile tahmini menzil: {mesafe} kwh")
    elif self.kapasite_kwh == 100:
        mesafe = 500
        print(f"Bu batarya ile tahmini menzil: {mesafe} kwh")
    else:
        mesafe = "Bilinmeyen batarya kapasitesi"
        print(mesafe)

# %%
class ElektrikliAraba(Araba):
    def __init__(self, marka, model, yil, batarya_kapasitesi):
        super().__init__(marka, model, yil)
        self.batarya = Batarya(batarya_kapasitesi)

    def benzin_doldur(self, litre):
        print("Hata: Elektrikli araba benzin doldurmaz.")

# %%
ikinci_elektrikli_arabam = ElektrikliAraba("Togg", "T10X", 2023, 100)
ikinci_elektrikli_arabam.batarya.bilgileri_goster()
ikinci_elektrikli_arabam.batarya.mesafe_hesapla()
# Out:
# Batarya kapasitesi: 100 kwh
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 ikinci_elektrikli_arabam = ElektrikliAraba("Togg", "T10X", 2023, 100)
#       2 ikinci_elektrikli_arabam.batarya.bilgileri_goster()
# ----> 3 ikinci_elektrikli_arabam.batarya.mesafe_hesapla()
#
# AttributeError: 'Batarya' object has no attribute 'mesafe_hesapla'

# %%
from araba import Araba

ilk_arabam = Araba("Honda", "Sivin", 2010)
ilk_arabam.bilgileri_goster()
# Out:
# 'Honda Sivin 2010 (0 km)'

# %%
from araba import Araba, Batarya

class ElektrikliAraba(Araba):
    def __init__(self, marka, model, yil, batarya_kapasitesi):
        super().__init__(marka, model, yil)
        self.batarya = Batarya(batarya_kapasitesi)

    def benzin_doldur(self, litre):
        print("Hata: Elektrikli araba benzin doldurmaz.")

# %%
ilk_elektrikli_arabam = ElektrikliAraba("Tesla", "Model 9", 2021, 75)
ilk_elektrikli_arabam.batarya.bilgileri_goster()
# Out:
# Batarya kapasitesi: 75 kwh

# %%
from random import randint

zar = randint(1, 6)

print(f"Atılan zar: {zar}")
# Out:
# Atılan zar: 5

# %%
from random import choice

oyuncular = ["Ali", "Veli", "Ayşe", "Fatma", "Mehmet", "Zeynep"]
kazanan = choice(oyuncular)
print(f"Bu turun kazananı: {kazanan}")
# Out:
# Bu turun kazananı: Fatma
