# %%
mesaj = "Uzun bir metin mesajı olabilir bu şekilde ifade edilebilir"
print(mesaj)
# Out:
# Uzun bir metin mesajı olabilir bu şekilde ifade edilebilir

# %%
print(mesaj)
# Out:
# Uzun bir metin mesajı olabilir bu şekilde ifade edilebilir

# %%
me saj "Test"
mesaj "Test"
# Out:
#   Cell In[4], line 1
#     me saj "Test"
#        ^
# SyntaxError: invalid syntax

# %%
mesaj = """bu mesajın "bu kısmı" önemli"""
print(mesaj)

print(mesaj.upper())
# Out:
# bu mesajın "bu kısmı" önemli
# BU MESAJIN "BU KISMI" ÖNEMLI

# %%
mesaj = mesaj.upper()
print(mesaj)
print(mesaj.lower())

print(mesaj.title())
# Out:
# BU MESAJIN "BU KISMI" ÖNEMLI
# bu mesajin "bu kismi" önemli
# Bu Mesajin "Bu Kismi" Önemli

# %%
isim = "yagiz"
soyisim = "uluyol"

print(f"{isim}.title() {soyisim}.title()")
# Out:
# yagiz.title() uluyol.title()

# %%
print("123" + "456")
print(123 + 456)
# Out:
# 123456
# 579

# %%
print(f"{123} + {456} = 123 + 456")
print(f"{123 +456} = 123 + 456")
# Out:
# 123 + 456 = 123 + 456
# 579 = 123 + 456

# %%
print("\tMerhaba,\nDünya")
# Out:
# 	Merhaba,
# Dünya

# %%
mesaj = "\tBoşluk  "
print(mesaj)
# Out:
# 	Boşluk

# %%
print(mesaj.strip())
print(mesaj.rstrip())
print(mesaj.lstrip())
# Out:
# Boşluk
# 	Boşluk
# Boşluk

# %%
print(3 + 5 * 2 - 8 / 4)
# Out:
# 11.0

# %%
a = 10
b = 3 
print(a + b)
# Out:
# 13

# %%
print(a ** b)
# Out:
# 1000

# %%
a = 10.5
b = 3.2
print(int(a ** b))
# Out:
# 1852

# %%
a = float(input("bir sayı giriniz:"))
b = float(input("bir sayı giriniz:"))
print(a + b)
# Out:
# 13.7
