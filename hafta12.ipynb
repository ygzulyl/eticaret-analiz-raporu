# %%
for uzayli in uzaylilar[:10]:
    if uzayli["renk"] == "sarı":
        uzayli["renk"] = "kırmızı"
        uzayli["puan"] = 15
        uzayli["hız"] = "hızlı"
    if uzayli["renk"] == "yeşil":
        uzayli["renk"] = "sarı"
        uzayli["puan"] = 10
        uzayli["hız"] = "orta"

for uzayli in uzaylilar[:15]:
    print(uzayli)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for uzayli in uzaylilar[:10]:
#       2     if uzayli["renk"] == "sarı":
#       3         uzayli["renk"] = "kırmızı"
#
# NameError: name 'uzaylilar' is not defined

# %%
pizza = {"kenar": "kalın",
         "malzemeler": ["mantar", "peynir", "sosis", "biber", "zeytin"]}

print(f"Aşağıdaki malzemelere sahip bir {pizza['kenar']} kenarlı pizza sipariş ettiniz:")
for malzeme in pizza['malzemeler']:
    print(f"- {malzeme}")
# Out:
# Aşağıdaki malzemelere sahip bir kalın kenarlı pizza sipariş ettiniz:
# - mantar
# - peynir
# - sosis
# - biber
# - zeytin

# %%
favori_diller = {
    "ali": ["python", "c++"],
    "ayşe": ["java", "ruby"],
    "mehmet": ["javascript"],
    "fatma": ["python", "java", "c#"]
}

for isim, diller in favori_diller.items():
    print(f"{isim.title()}'in favori proglamlama dilleri şunlardır:")
    for dil in diller:
        print(f"- {dil.title()}")
# Out:
# Ali'in favori proglamlama dilleri şunlardır:
# - Python
# - C++
# Ayşe'in favori proglamlama dilleri şunlardır:
# - Java
# - Ruby
# Mehmet'in favori proglamlama dilleri şunlardır:
# - Javascript
# Fatma'in favori proglamlama dilleri şunlardır:
# - Python
# - Java
# - C#

# %%
kullanicilar = {
    "aeinstein": {
        "ad": "albert",
        "soyad": "einstein",
        "doğum_yılı": 1870,
        "şehir": "princeton"
    }
    "mcurie": {
        "ad": "marie",
        "soyad": "curie",
        "doğum_yılı": 1867,
        "şehir": "paris"
    }
}

for kullanici_adi, bilgiler in kullanicilar.items():
    print(f"Kullanıcı Adı: {kullanici_adi}")
    tam_ad = f"{bilgiler['ad'].title()} {bilgiler['soyad'].title()}"
    doğum_yılı = bilgiler['doğum_yılı']
    şehir = bilgiler['şehir'].title()
    print(f"\tTam Ad: {tam_ad}"
          f"\n\tDoğum Yılı: {doğum_yılı}"
          f"\n\tŞehir: {şehir}")
# Out:
#   Cell In[25], line 2
#     "aeinstein": {
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
